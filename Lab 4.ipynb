# %% [markdown]
# ## Introduction
# In this lab, three unrelated datasets were partially cleaned. The biggest single problem that could be tackled was the issue of columns that need to be removed.

# %%
#include aliased modules
import math as m
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset Preparation - Sales

# %% [markdown]
# The biggest challenege with this dataset were the ID columns. These columns prevented this data from being properly analyzed. I was content with having NaNs being counted as such and not zero as that would heavily skew any results.

# %% [markdown]
# Reading the data in and displaying:

# %%
df = pd.read_csv("Sales_Data.csv", encoding= 'ISO-8859-1')
df.head(50)
            
#Account for headers
#Drop first four columns
# Out:
#     Unnamed: 0              event_id        primary_act_id  \
# 0            1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1            2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2            3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3            4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4            5  55b5f67e618557929f48  91c03a34b562436efa3c
# 5            6  4f10fd8b9f550352bd56  ac4b847b3fde66f2117e
# 6            7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 7            8  593b910d17913d7101cb  91c03a34b562436efa3c
# 8            9  0fb4e7152e09a40ffedd  0efaba7ce3f0d7466b42
# 9           10  93fce8094d89e0a94aac  f6425a3223e73ea6de5a
# 10          11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 11          12  6adcf8b2dc8a761b22b7  094156ef72361776c8ee
# 12          13  d3c8f5fb844690fb5af6  732d4f52a3ac2b7de8ef
# 13          14  5c7d36b783905ba488f4  34ad0e9254b8f7d1cbe0
# 14          15  e68754d15ef2b8694b26  6e3df9919c998817e1b1
# ...

# %% [markdown]
# Removing unecessary columns. The content of these columns may have some use, but for our purposes they only muddled the data.

# %%
df=df.drop('event_id', 1)
df=df.drop('primary_act_id', 1)
df=df.drop('purch_party_lkup_id', 1)
df=df.drop('secondary_act_id', 1)

df.head(50)
# Out:
#     Unnamed: 0                                         event_name  \
# 0            1  Xfinity Center Mansfield Premier Parking: Flor...
# 1            2      Gorge Camping - dave matthews band - sept 3-7
# 2            3        Dodge Theatre Adams Street Parking - benise
# 3            4  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4            5                      Premier Parking - motley crue
# 5            6                          Fast Lane Access: Journey
# 6            7  Phil Lesh & friends-pnc bank arts center holmd...
# 7            8  Star Parking Presented By Hertz: Train -  whit...
# 8            9                Brad Paisley: Hertz Premier Parking
# 9           10                                            Shlohmo
# 10          11  Cricket Pavilion Premier Parking: Earth Wind A...
# 11          12                 Blake Shelton: Presented By Gildan
# 12          13        Skip The Line: Pierce The Line/all Time Low
# ...

# %% [markdown]
# ## Dataset Preparation - School Attendance

# %% [markdown]
# This data was different in that there was a row of parenthesized data in conjunction with other data. There were also rows that didn't correspond to a state, and these had to be removed. Also, there ‡ and † symbols distributed throughout the data. These would have to be removed but I was not able to do so for either these symbols or the prenthesis (which I later removed by dropping the column containing them). This is one area for futher exploration.

# %% [markdown]
# Reading the data in and displaying (note that the first three rows were counted as header data):

# %%
#read in and display data
df2 = pd.read_csv("US_School_Attendance.csv",
                 header=3)
                

df2.head(500)

#Account for headers and remove parenthesis
#Drop rows that don't correspond to a state
#Account for ‡ and (†) symbols
# Out:
#                                                     1     2 Unnamed: 2    3  \
# 0                              United States ........  93.1     (0.22)  6.6
# 1                           Alabama .................  93.8     (1.24)  7.0
# 2                           Alaska ..................  89.9     (1.22)  6.5
# 3                           Arizona .................  89.0     (2.95)  6.4
# 4                           Arkansas ................  91.8     (1.35)  6.9
# 5                           California ..............  93.2     (0.71)  6.2
# 6                                                 NaN   NaN        NaN  NaN
# 7                           Colorado ................  93.9     (0.44)  7.0
# 8                           Connecticut .............  87.9     (2.98)  6.5
# 9                           Delaware ................  89.8     (1.75)  6.7
# 10                          District of Columbia ....  91.2     (1.27)  6.9
# ...

# %% [markdown]
# Removing uneccesary rows. Given enough time, I would do this for all non-state rows. Here, I removed the row that simply said "NOTE: Averages reflect data reorted by school...". In this row there was no data; it seemed more appropriate for this information to be included as metadata and available seperatly. The data was then displayed to validate removal of this row.

# %%
#Removing row 63 and displaying data to ensure removal
df2.drop(df2.index[63], inplace=True)
df2.head(500)
# Out:
#                                                     1     2 Unnamed: 2    3  \
# 0                              United States ........  93.1     (0.22)  6.6
# 1                           Alabama .................  93.8     (1.24)  7.0
# 2                           Alaska ..................  89.9     (1.22)  6.5
# 3                           Arizona .................  89.0     (2.95)  6.4
# 4                           Arkansas ................  91.8     (1.35)  6.9
# 5                           California ..............  93.2     (0.71)  6.2
# 6                                                 NaN   NaN        NaN  NaN
# 7                           Colorado ................  93.9     (0.44)  7.0
# 8                           Connecticut .............  87.9     (2.98)  6.5
# 9                           Delaware ................  89.8     (1.75)  6.7
# 10                          District of Columbia ....  91.2     (1.27)  6.9
# ...

# %% [markdown]
# Removing columns with parenthesis. Given enough time, I would do this for all of the data. This was done becuase the parenthesis posed a potential problem if any sort of modeling was done on the data. The data was then displayed to ensure removal.

# %%
#import re
#s=['93.8', '(1.24)']
#df2.s.replace(re.escape('(1.24)'),"1.24")
#https://stackoverflow.com/questions/20894525/how-to-remove-parentheses-and-all-data-within-using-pandas-python


#Renaming and removing the column
#Printing data to ensure removal
df2.rename({"Unnamed: 2": "Unnamed_2"}, axis="columns", inplace=True)
df2=df2.drop('Unnamed_2', 1)

df2.head(500)
# Out:
#                                                     1     2    3 Unnamed: 4  \
# 0                              United States ........  93.1  6.6     (0.02)
# 1                           Alabama .................  93.8  7.0     (0.07)
# 2                           Alaska ..................  89.9  6.5     (0.05)
# 3                           Arizona .................  89.0  6.4     (0.09)
# 4                           Arkansas ................  91.8  6.9     (0.06)
# 5                           California ..............  93.2  6.2     (0.07)
# 6                                                 NaN   NaN  NaN        NaN
# 7                           Colorado ................  93.9  7.0     (0.05)
# 8                           Connecticut .............  87.9  6.5     (0.09)
# 9                           Delaware ................  89.8  6.7     (0.09)
# 10                          District of Columbia ....  91.2  6.9     (0.21)
# ...

# %% [markdown]
# ## Dataset Preparation - Candy

# %% [markdown]
# This data was interesting to say the least. There were so many columns containing so much unusable data that it seemed like the only usuable data were the responses to the specific candies (these responses were probably selected by users from a drop down menu instead of having them write their reponse in).

# %% [markdown]
# Reading in and displaying the data:

# %%
df3 = pd.read_csv("BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses - Form Responses 1.csv")
            
df3.head(500)
# Out:
#                Timestamp  \
# 0     10/24/2016 5:09:23
# 1     10/24/2016 5:09:55
# 2     10/24/2016 5:13:07
# 3     10/24/2016 5:14:17
# 4     10/24/2016 5:14:25
# 5     10/24/2016 5:16:43
# 6     10/24/2016 5:16:51
# 7     10/24/2016 5:16:55
# 8     10/24/2016 5:17:49
# 9     10/24/2016 5:18:51
# 10    10/24/2016 5:20:21
# 11    10/24/2016 5:21:20
# 12    10/24/2016 5:21:28
# 13    10/24/2016 5:22:13
# 14    10/24/2016 5:22:31
# 15    10/24/2016 5:24:08
# 16    10/24/2016 5:24:11
# 17    10/24/2016 5:26:18
# 18    10/24/2016 5:26:35
# 19    10/24/2016 5:27:00
# 20    10/24/2016 5:30:40
# 21    10/24/2016 5:31:49
# 22    10/24/2016 5:33:19
# 23    10/24/2016 5:33:28
# 24    10/24/2016 5:34:36
# 25    10/24/2016 5:34:37
# 26    10/24/2016 5:34:40
# 27    10/24/2016 5:35:46
# 28    10/24/2016 5:36:13
# 29    10/24/2016 5:36:44
# ..                   ...
# 470  10/24/2016 11:21:18
# 471  10/24/2016 11:21:49
# 472  10/24/2016 11:22:30
# 473  10/24/2016 11:23:29
# ...

# %% [markdown]
# Renaming and removing unnecessary columns.

# %%
#list columns
df3.columns
df3_columns=df3.columns

#Rename the column so that it can be deleted
df3.rename({"How old are you?": "How_old_are_you",
           "Are you going actually going trick or treating yourself": "trick_or_treat"}, axis="columns", inplace=True)
#Drop the column
df3=df3.drop('How_old_are_you', 1)
#df3=df3.drop('trick_or_treat', 1)
#https://stackoverflow.com/questions/13411544/delete-column-from-pandas-dataframe-using-del-df-column-name

#print data to be sure that it dropped


df3.head(500)
# Out:
#                Timestamp  \
# 0     10/24/2016 5:09:23
# 1     10/24/2016 5:09:55
# 2     10/24/2016 5:13:07
# 3     10/24/2016 5:14:17
# 4     10/24/2016 5:14:25
# 5     10/24/2016 5:16:43
# 6     10/24/2016 5:16:51
# 7     10/24/2016 5:16:55
# 8     10/24/2016 5:17:49
# 9     10/24/2016 5:18:51
# 10    10/24/2016 5:20:21
# 11    10/24/2016 5:21:20
# 12    10/24/2016 5:21:28
# 13    10/24/2016 5:22:13
# 14    10/24/2016 5:22:31
# 15    10/24/2016 5:24:08
# 16    10/24/2016 5:24:11
# 17    10/24/2016 5:26:18
# 18    10/24/2016 5:26:35
# 19    10/24/2016 5:27:00
# 20    10/24/2016 5:30:40
# 21    10/24/2016 5:31:49
# 22    10/24/2016 5:33:19
# 23    10/24/2016 5:33:28
# 24    10/24/2016 5:34:36
# 25    10/24/2016 5:34:37
# 26    10/24/2016 5:34:40
# 27    10/24/2016 5:35:46
# 28    10/24/2016 5:36:13
# 29    10/24/2016 5:36:44
# ..                   ...
# 470  10/24/2016 11:21:18
# 471  10/24/2016 11:21:49
# 472  10/24/2016 11:22:30
# 473  10/24/2016 11:23:29
# ...

# %% [markdown]
# Given more time, I would rename and remove every column except for the columns pertaining to the specific candies. If I had done this, I believe that the below cell would work and I could use the number values assigned to the specific candy responses in order to find mean, meadian, min, and max for each candy.

# %%
#Assign numbers to every entry in order to do mathematical calculations
pd.factorize(df3)
#https://stackoverflow.com/questions/42350029/assign-a-number-to-each-unique-value-in-a-list

df3.head(500)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-c27775e711cc> in <module>()
# ----> 1 pd.factorize(df3)
#       2 #https://stackoverflow.com/questions/42350029/assign-a-number-to-each-unique-value-in-a-list
#       3
#       4 df3.head(500)
#
# /anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     608     # should happen here.
#     609
# --> 610     values = _ensure_arraylike(values)
#     611     original = values
#     612
#
# ...

# %%
df3.values
# Out:
# array([['10/24/2016 5:09:23', 'No', 'Male', ..., 'South to North',
#         'Science: Latest News and Headlines', nan],
#        ['10/24/2016 5:09:55', 'No', 'Male', ..., 'East to West',
#         'Science: Latest News and Headlines', nan],
#        ['10/24/2016 5:13:07', 'No', 'Female', ..., 'East to West',
#         'Science: Latest News and Headlines', nan],
#        ...,
#        ['10/30/2016 11:06:11', 'No', 'Male', ...,
#         'nne to east to nnw to s to n',
#         'Science: Latest News and Headlines', nan],
#        ['10/30/2016 16:07:27', 'No', 'Male', ..., 'East to West',
#         'Science: Latest News and Headlines', nan],
#        ['10/30/2016 17:06:46', 'Yes', 'Female', ..., 'East to West',
#         'Daily Dish', nan]], dtype=object)

# %%
pd.factorize('DESPAIR', 'MEH', "JOY")
#https://stackoverflow.com/questions/42350029/assign-a-number-to-each-unique-value-in-a-list
# Out:
# (array([0, 0, 0, 0, 0, 0, 0]), array(['DESPAIR'], dtype=object))

# %%
df3.['DESPAIR', 'MEH', 'JOY'],[1,2,3]
print(df3)
# Out:
#   File "<ipython-input-31-123bab6306d8>", line 1
#     df3.['DESPAIR', 'MEH', 'JOY'],[1,2,3]
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Conclusion
# For all three datasets, I erred on the side of having a more narrow focus when it would come time to model the data. This meant that I cut, or began to cut, more data. The candy data was without a doubt the worst of the three datsets. It was full of inconsistent responses, clear dishonesty, and large gaps in the data. Overall, I'm am not sure how effective any of my cleaning methods were. With the candy data, even if I had had the time to remove all of the irrelevent columns, without being able to substitute a number for the DESPAIR, MEH, JOY values not much could be done with the data. Unless a bar chart was made with these responses as the bins. This is one area for future exploration. The sales data was in the middle in terms of how much cleaning would have to be done. It seemed important to keep the NaNs as such and refrain from substituting zeroes for them. This was becuase there was an instance where there actual numbers in these places and so flooding the data with zeroes would dramatically alter any analysis. It was also important to remove the ID columns as they did not seem to offer any usuable information and only muddles up the data. I am not sure what they were or what use they had, perhpas this is another area for future exploration. The school attendance data was the cleanest dataset of the three. The only main issues with it were that there was some unneccesary data included, there were parenthesis, and the states had elipses after their names. The elipses would not have caused a major problem in a simple analysis, but in the long run they would. The removal of the elipses and the remova of the parenthesis without alterin the data is another area for further exploration. I removed parenthesis columns because they would have alterted calculation.

# %% [markdown]
# ## Aknowledgements
# Much of the code came from Ms. Sconyers. Renaming the column headers came from:
# https://stackoverflow.com/questions/13411544/delete-column-from-pandas-dataframe-using-del-df-column-name from the user LondonRob. The attempt to remove parenthesis came from:
# https://stackoverflow.com/questions/20894525/how-to-remove-parentheses-and-all-data-within-using-pandas-python from the user Alexis. My attempt to factorize my data came from:
# https://stackoverflow.com/questions/42350029/assign-a-number-to-each-unique-value-in-a-list from the user Cleb.
